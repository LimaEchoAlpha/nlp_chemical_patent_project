# %%
# !nvcc --version

# %%
# !python --version

# %%
# !apt-get install python3.7-dev python3.7-venv

# %%
# !python -m venv .env
# !source .env/bin/activate
# !pip install -U pip setuptools wheel
# !pip install -U spacy[cuda111]
# !pip install -U spacy[cuda111,transformers]

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy
spacy.__version__

# %%
spacy.prefer_gpu()

# %%
spacy.require_gpu()
# Out:
# True

# %%
# !python -m spacy validate

# %%
# !python -m spacy train -g 0 drive/MyDrive/W266/chemical_patent_cer_ee/raw_data/config_spacy.cfg --paths.train drive/MyDrive/W266/chemical_patent_cer_ee/raw_data/sample_data.spacy --paths.dev drive/MyDrive/W266/chemical_patent_cer_ee/raw_data/sample_data.spacy --output drive/MyDrive/W266/chemical_patent_cer_ee/raw_data/
# Out:
# ℹ Saving to output directory:
# drive/MyDrive/W266/chemical_patent_cer_ee/raw_data
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-11-12 02:37:19,920] [INFO] Set up nlp object from config
# [2021-11-12 02:37:19,933] [INFO] Pipeline: ['transformer', 'ner']
# [2021-11-12 02:37:19,938] [INFO] Created vocabulary
# [2021-11-12 02:37:19,940] [INFO] Finished initializing nlp object
# Downloading: 100% 481/481 [00:00<00:00, 696kB/s]
# Downloading: 100% 878k/878k [00:00<00:00, 4.18MB/s]
# Downloading: 100% 446k/446k [00:00<00:00, 3.23MB/s]
# Downloading: 100% 1.29M/1.29M [00:00<00:00, 7.21MB/s]
# Downloading: 100% 478M/478M [00:25<00:00, 19.7MB/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# ...

# %% [markdown]
# Convert input files to json then to spacy format

# %%
# !python -m spacy convert drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_train.csv drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ -t json -n 1 -c iob
# Out:
# ℹ Auto-detected token-per-line NER format
# ⚠ Document delimiters found, automatic document segmentation with `-n`
# disabled.
# ✔ Generated output file (1 documents):
# drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_train.json

# %%
# !python -m spacy convert drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_dev.csv drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ -t json -n 1 -c iob
# Out:
# ℹ Auto-detected token-per-line NER format
# ⚠ Document delimiters found, automatic document segmentation with `-n`
# disabled.
# ✔ Generated output file (1 documents):
# drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_dev.json

# %%
# !python -m spacy convert drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_train.json drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/ -t spacy
# Out:
# ✔ Generated output file (900 documents):
# /content/drive/MyDrive/W266/chemical_patent_cer_ee/models/baseline/ee_ner_train.spacy

# %%
# !python -m spacy convert drive/MyDrive/W266/chemical_patent_cer_ee/data/conll/ee_ner_dev.json drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/ -t spacy
# Out:
# ✔ Generated output file (225 documents):
# /content/drive/MyDrive/W266/chemical_patent_cer_ee/models/baseline/ee_ner_dev.spacy

# %%
# !python -m spacy init fill-config drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/sm_config.cfg drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/config_spacy.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/config_spacy.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_spacy.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train -g 0 drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/config_spacy.cfg --paths.train drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/ee_ner_train.spacy --paths.dev drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/ee_ner_dev.spacy --output drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline/
# Out:
# ℹ Saving to output directory:
# drive/MyDrive/W266/chemical_patent_cer_ee/models/sm_baseline
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-11-12 04:30:32,191] [INFO] Set up nlp object from config
# [2021-11-12 04:30:32,206] [INFO] Pipeline: ['transformer', 'ner']
# [2021-11-12 04:30:32,212] [INFO] Created vocabulary
# [2021-11-12 04:30:32,214] [INFO] Finished initializing nlp object
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
