# %% [markdown]
# #### Set-up for Colab
# Install dependencies, mount drive, etc.

# %%
#pip install tensorflow==2.0.0

# %%
#pip install -q -U tensorflow-text

# %%
#pip install -q tf-models-official

# %%
pip uninstall tensorflow

# %%
pip install tensorflow==2.5.0

# %%
pip install transformers

# %%
pip install bert-for-tf2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/MyDrive/MIDS/chemical_patent_cer_ee'
#path = '..'

# %% [markdown]
# #### Import Libraries

# %%
import os
import io
import re
import sys
import sys
sys.path.append('/content/drive/MyDrive/MIDS/chemical_patent_cer_ee/notebooks')

import numpy as np
import pandas as pd
import argparse
from time import time
import matplotlib.pyplot as plt

import pickle
from csv import reader

import tensorflow as tf
from transformers import BertTokenizer
import bert

from sre_inputs import *
from train_test import *
from sre_models import *

# %% [markdown]
# #### BERT Model
# - Load BERT model and tokenizer
# - Set max length for inputs

# %%
# path for bert model
bert_model_dir = f'{path}/bert/bert_mini'
bert_type = bert_model_dir.split('/')[-1]

# set tokenizer
vocab_file = os.path.join(bert_model_dir, "vocab.txt")
tokenizer = BertTokenizer(vocab_file=vocab_file, do_lower_case=False)
#tokenizer = BertTokenizer.from_pretrained(vocab_file=vocab_file, do_lower_case=False)

# set BERT model
bert_params = bert.params_from_pretrained_ckpt(bert_model_dir)
bert = bert.BertModelLayer.from_params(bert_params, name="bert")

# set max length for inputs
max_length = 500

# set parameters for model type
marker_type = 'ner' # 'em', 'ner', or 'std'
head_type = 'ner' # 'cls', 'start', 'pool', or 'ner'
subsampled = False

# %% [markdown]
# #### Data
# - Upload preprocessed chemical patent file(s)
# - Use `sre_inputs` module to generate inputs for model
# - Sample only: split into train/test using `train_test` module
# - Need to one hot encode labels before using in model
#
# *NB: Make sure that preprocessed data being uploaded and parameters chosen for generating inputs **both** match the type of model it will be used for!*

# %%
#### SAMPLE PROCESSING ####

# path for preprocessed data
if marker_type == 'em' or marker_type == 'std':
    sample_path = f'{path}/data/sre_em/sre_em_sample.csv'
elif marker_type == 'ner':
    sample_path = f'{path}/data/sre_ner/sre_ner_sample.csv'

# generate inputs for model
if marker_type == 'em' or marker_type == 'ner':
    all_lists = generate_entity_inputs(sample_path, tokenizer, marker_type, head_type, max_length)
elif marker_type == 'std':
    all_lists = generate_standard_inputs(sample_path, tokenizer, max_length)

# SAMPLE ONLY: split into train/test
train_all, test_all = train_test_split(all_lists)

# generate inputs and labels
# one hot encode labels
sample_inputs_train = [x for x in train_all[0][:5]]
sample_labels_train = train_all[1]
sample_labels_train = tf.one_hot(sample_labels_train, depth=3)

sample_inputs_test = [x for x in test_all[0][:5]]
sample_labels_test = test_all[1]
sample_labels_test = tf.one_hot(sample_labels_test, depth=3)

# %%
#### TRAIN/DEV DATASET PROCESSING ####

# paths for preprocessed data
if (marker_type == 'em' or marker_type == 'std') and not subsampled:
    train_path = f'{path}/data/sre_em/sre_em_train.csv'
    dev_path = f'{path}/data/sre_em/sre_em_dev.csv'
elif (marker_type == 'em' or marker_type == 'std') and subsampled:
    train_path = f'{path}/data/sre_em/sre_em_train_subsampled.csv'
    dev_path = f'{path}/data/sre_em/sre_em_dev_subsampled.csv'
elif marker_type == 'ner' and not subsampled:
    train_path = f'{path}/data/sre_ner/sre_ner_train.csv'
    dev_path = f'{path}/data/sre_ner/sre_ner_dev.csv'
elif marker_type == 'ner' and subsampled:
    train_path = f'{path}/data/sre_ner/sre_ner_train_subsampled.csv'
    dev_path = f'{path}/data/sre_ner/sre_ner_dev_subsampled.csv'

print(f'Loaded {train_path}')
print(f'Loaded {dev_path}')

# generate inputs for model
if marker_type == 'em' or marker_type == 'ner':
    train_lists = generate_entity_inputs(train_path, tokenizer, marker_type, head_type, max_length)
    dev_lists = generate_entity_inputs(dev_path, tokenizer, marker_type, head_type, max_length)
elif marker_type == 'std':
    train_lists = generate_standard_inputs(train_path, tokenizer, max_length)
    dev_lists = generate_standard_inputs(dev_path, tokenizer, max_length)

# generate inputs and labels
# one hot encode labels
model_inputs_train = [x for x in train_lists[0][:5]]
train_labels = train_lists[1]
model_labels_train = tf.one_hot(train_labels, depth=3)

model_inputs_dev = [x for x in dev_lists[0][:5]]
dev_labels = dev_lists[1]
model_labels_dev = tf.one_hot(dev_labels, depth=3)
# Out:
# Loaded drive/MyDrive/MIDS/chemical_patent_cer_ee/data/sre_ner/sre_ner_train.csv
# Loaded drive/MyDrive/MIDS/chemical_patent_cer_ee/data/sre_ner/sre_ner_dev.csv

# %%
#### TEST DATASET PROCESSING ####

# path for preprocessed data
if marker_type == 'em' or marker_type == 'std':
    test_path = f'{path}/data/sre_em/sre_em_test.csv'
elif marker_type == 'ner':
    test_path = f'{path}/data/sre_ner/sre_ner_test.csv'

# generate inputs for model
if marker_type == 'em' or marker_type == 'ner':
    test_lists = generate_entity_inputs(test_path, tokenizer, marker_type, head_type, max_length)
elif marker_type == 'std':
    test_lists = generate_standard_inputs(test_path, tokenizer, max_length)

# generate inputs and labels
# one hot encode labels
model_inputs_test = [x for x in test_lists[0][:5]]
test_labels = test_lists[1]
model_labels_test = tf.one_hot(test_labels, depth=3)

# %% [markdown]
# #### Run Model(s)

# %%
#### SAMPLE RUN ####

tf.keras.backend.clear_session()
#tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

epochs = 1
batch_size = 16

if head_type == 'cls':
    model = sre_cls_model(bert, max_length)
elif head_type == 'start':
    model = sre_start_model(bert, max_length)
elif head_type == 'pool':
    model = sre_pool_model(bert, max_length)
elif head_type == 'ner':
    model = sre_pool_model(bert, max_length)

if marker_type == 'std' or head_type == 'cls':
    model.fit(
        sample_inputs_train[:3], 
        {"sre": sample_labels_train},
        validation_data=(sample_inputs_test[:3], {"sre": sample_labels_test}),
        epochs=epochs,
        batch_size=batch_size
    )
else:
    model.fit(
        sample_inputs_train, 
        {"sre": sample_labels_train},
        validation_data=(sample_inputs_test, {"sre": sample_labels_test}),
        epochs=epochs,
        batch_size=batch_size
    )
# Out:
# === SRE Max Pool Model ===
# BERT layer output: KerasTensor(type_spec=TensorSpec(shape=(None, 500, 256), dtype=tf.float32, name=None), name='bert/encoder/layer_3/output/LayerNorm/add_1:0', description="created by layer 'bert'")
# Prediction: KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='sre/Softmax:0', description="created by layer 'sre'")
#
# Model: "sre_pool"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 500)]        0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 500)]        0
# __________________________________________________________________________________________________
# e1_mask (InputLayer)            [(None, 500)]        0
# __________________________________________________________________________________________________
# e2_mask (InputLayer)            [(None, 500)]        0
# __________________________________________________________________________________________________
# bert (BertModelLayer)           (None, 500, 256)     11104768    input_ids[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 500)          0           e1_mask[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_3 (TFOpLam (None, 500)          0           e2_mask[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 500, 256)     0           bert[0][0]
# __________________________________________________________________________________________________
# tf.math.count_nonzero (TFOpLamb (None,)              0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 500, 256)     0           bert[0][0]
# __________________________________________________________________________________________________
# tf.math.count_nonzero_1 (TFOpLa (None,)              0           tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.boolean_mask (Slic (None, 256)          0           tf.convert_to_tensor[0][0]
#                                                                  tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None,)              0           tf.math.count_nonzero[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.boolean_mask_1 (Sl (None, 256)          0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None,)              0           tf.math.count_nonzero_1[0][0]
# __________________________________________________________________________________________________
# tf.RaggedTensor.from_row_length (None, None, 256)    0           tf.compat.v1.boolean_mask[0][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.RaggedTensor.from_row_length (None, None, 256)    0           tf.compat.v1.boolean_mask_1[0][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# input.to_tensor (InstanceMethod (None, None, 256)    0           tf.RaggedTensor.from_row_lengths[
# __________________________________________________________________________________________________
# input.to_tensor_1 (InstanceMeth (None, None, 256)    0           tf.RaggedTensor.from_row_lengths_
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (None, 256)          0           input.to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_1 (TFOpLambd (None, 256)          0           input.to_tensor_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           tf.math.reduce_max[0][0]
#                                                                  tf.math.reduce_max_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          131328      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, 500)]        0
# __________________________________________________________________________________________________
# sre (Dense)                     (None, 3)            771         dropout[0][0]
# ==================================================================================================
# Total params: 11,236,867
# Trainable params: 11,236,867
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 88/88 [==============================] - 99s 1s/step - loss: 0.8807 - categorical_accuracy: 0.6186 - recall: 0.5649 - precision: 0.6417 - val_loss: 0.7201 - val_categorical_accuracy: 0.6838 - val_recall: 0.6546 - val_precision: 0.6991

# %%
#### TRAIN/DEV RUN ####

tf.keras.backend.clear_session()
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

epochs = 10
batch_size = 32

if head_type == 'cls':
    model = sre_cls_model(bert, max_length)
elif head_type == 'start':
    model = sre_start_model(bert, max_length)
elif head_type == 'pool':
    model = sre_pool_model(bert, max_length)
elif head_type == 'ner':
    model = sre_pool_model(bert, max_length)

if marker_type == 'std' or head_type == 'cls':
    model.fit(
        model_inputs_train[:3], 
        {"sre": model_labels_train},
        validation_data=(model_inputs_dev[:3], {"sre": model_labels_dev}),
        epochs=epochs,
        batch_size=batch_size
    )
else:
    model.fit(
    model_inputs_train, 
    {"sre": model_labels_train},
    validation_data=(model_inputs_dev, {"sre": model_labels_dev}),
    epochs=epochs,
    batch_size=batch_size
)
# Out:
# === SRE Max Pool Model ===
# BERT layer output: KerasTensor(type_spec=TensorSpec(shape=(None, 500, 256), dtype=tf.float32, name=None), name='bert/encoder/layer_3/output/LayerNorm/add_1:0', description="created by layer 'bert'")
# Prediction: KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='sre/Softmax:0', description="created by layer 'sre'")
#
# Model: "sre_pool"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 500)]        0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 500)]        0
# __________________________________________________________________________________________________
# e1_mask (InputLayer)            [(None, 500)]        0
# __________________________________________________________________________________________________
# e2_mask (InputLayer)            [(None, 500)]        0
# __________________________________________________________________________________________________
# bert (BertModelLayer)           (None, 500, 256)     11104768    input_ids[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 500)          0           e1_mask[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_3 (TFOpLam (None, 500)          0           e2_mask[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 500, 256)     0           bert[2][0]
# __________________________________________________________________________________________________
# tf.math.count_nonzero (TFOpLamb (None,)              0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 500, 256)     0           bert[2][0]
# __________________________________________________________________________________________________
# tf.math.count_nonzero_1 (TFOpLa (None,)              0           tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.boolean_mask (Slic (None, 256)          0           tf.convert_to_tensor[0][0]
#                                                                  tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None,)              0           tf.math.count_nonzero[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.boolean_mask_1 (Sl (None, 256)          0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None,)              0           tf.math.count_nonzero_1[0][0]
# __________________________________________________________________________________________________
# tf.RaggedTensor.from_row_length (None, None, 256)    0           tf.compat.v1.boolean_mask[0][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.RaggedTensor.from_row_length (None, None, 256)    0           tf.compat.v1.boolean_mask_1[0][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# input.to_tensor (InstanceMethod (None, None, 256)    0           tf.RaggedTensor.from_row_lengths[
# __________________________________________________________________________________________________
# input.to_tensor_1 (InstanceMeth (None, None, 256)    0           tf.RaggedTensor.from_row_lengths_
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (None, 256)          0           input.to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_1 (TFOpLambd (None, 256)          0           input.to_tensor_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           tf.math.reduce_max[0][0]
#                                                                  tf.math.reduce_max_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          131328      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, 500)]        0
# __________________________________________________________________________________________________
# sre (Dense)                     (None, 3)            771         dropout[0][0]
# ==================================================================================================
# Total params: 11,236,867
# Trainable params: 11,236,867
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 1432/1432 [==============================] - 1294s 902ms/step - loss: 0.7463 - categorical_accuracy: 0.6871 - recall: 0.6385 - precision: 0.7095 - val_loss: 0.6026 - val_categorical_accuracy: 0.7327 - val_recall: 0.7019 - val_precision: 0.7538
# Epoch 2/10
# 1432/1432 [==============================] - 1286s 898ms/step - loss: 0.5872 - categorical_accuracy: 0.7465 - recall: 0.7127 - precision: 0.7671 - val_loss: 0.5305 - val_categorical_accuracy: 0.7734 - val_recall: 0.7488 - val_precision: 0.7893
# Epoch 3/10
# 1432/1432 [==============================] - 1282s 896ms/step - loss: 0.5385 - categorical_accuracy: 0.7718 - recall: 0.7450 - precision: 0.7886 - val_loss: 0.4984 - val_categorical_accuracy: 0.7920 - val_recall: 0.7685 - val_precision: 0.8108
# Epoch 4/10
# 1432/1432 [==============================] - 1288s 900ms/step - loss: 0.5115 - categorical_accuracy: 0.7844 - recall: 0.7632 - precision: 0.7989 - val_loss: 0.4811 - val_categorical_accuracy: 0.8003 - val_recall: 0.7815 - val_precision: 0.8123
# Epoch 5/10
# 1432/1432 [==============================] - 1286s 898ms/step - loss: 0.4948 - categorical_accuracy: 0.7914 - recall: 0.7727 - precision: 0.8047 - val_loss: 0.4620 - val_categorical_accuracy: 0.8118 - val_recall: 0.7951 - val_precision: 0.8226
# Epoch 6/10
# 1432/1432 [==============================] - 1288s 900ms/step - loss: 0.4821 - categorical_accuracy: 0.7972 - recall: 0.7806 - precision: 0.8098 - val_loss: 0.4508 - val_categorical_accuracy: 0.8174 - val_recall: 0.8039 - val_precision: 0.8270
# Epoch 7/10
# 1432/1432 [==============================] - 1285s 898ms/step - loss: 0.4714 - categorical_accuracy: 0.8041 - recall: 0.7875 - precision: 0.8149 - val_loss: 0.4411 - val_categorical_accuracy: 0.8199 - val_recall: 0.8097 - val_precision: 0.8291
# Epoch 8/10
# 1432/1432 [==============================] - 1287s 899ms/step - loss: 0.4623 - categorical_accuracy: 0.8077 - recall: 0.7930 - precision: 0.8176 - val_loss: 0.4359 - val_categorical_accuracy: 0.8227 - val_recall: 0.8104 - val_precision: 0.8317
# Epoch 9/10
# 1432/1432 [==============================] - 1284s 897ms/step - loss: 0.4547 - categorical_accuracy: 0.8107 - recall: 0.7965 - precision: 0.8213 - val_loss: 0.4297 - val_categorical_accuracy: 0.8239 - val_recall: 0.8128 - val_precision: 0.8329
# Epoch 10/10
# 1432/1432 [==============================] - 1284s 897ms/step - loss: 0.4486 - categorical_accuracy: 0.8163 - recall: 0.8033 - precision: 0.8261 - val_loss: 0.4238 - val_categorical_accuracy: 0.8262 - val_recall: 0.8178 - val_precision: 0.8352

# %%
# evaluate model on test data
print('Evaluate on test data')

if marker_type == 'std' or head_type == 'cls':
    results = model.evaluate(model_inputs_test[:3], model_labels_test, batch_size=batch_size)
else:
    results = model.evaluate(model_inputs_test, model_labels_test, batch_size=batch_size)

# generate predictions on new data (probabilities -- the output of the last layer)
print("Generate predictions for new samples")

if marker_type == 'std' or head_type == 'cls':
    predictions = model.predict(model_inputs_test[:3])
else: 
    predictions = model.predict(model_inputs_test)

print("predictions shape:", predictions.shape)

# save stuff
if subsampled:
    model_name = f'SRE_{bert_type}_{marker_type}_{head_type}_sub'
else:
    model_name = f'SRE_{bert_type}_{marker_type}_{head_type}'

# save results and predictions
outputs = [results, predictions]
with open(f'{path}/results/{model_name}.pickle', "wb") as f:
    pickle.dump(outputs, f)

# save model
# model.save(f'{path}/models/{model_name}')
# Out:
# Evaluate on test data
# 579/579 [==============================] - 357s 614ms/step - loss: 0.4311 - categorical_accuracy: 0.8225 - recall: 0.8127 - precision: 0.8292
# Generate predictions for new samples
# predictions shape: (18515, 3)

# %%
# # how to open saved file
# with open(f'{path}/results/{model_name}.pickle', "rb") as f:
#     saved_outputs = pickle.load(f)

# %%
# OPTIONAL: visualize model
#tf.keras.utils.plot_model(model, show_shapes=True, dpi=48)
